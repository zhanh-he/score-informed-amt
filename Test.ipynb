# %% [markdown]
# # Evaluation Results (Tables 1 & 2 in Paper)
#
# Please check the results on this notebook, as reported in our paper (Table 1 & 2). You can reproduce these results by requested the ckpt files from us.
#
# Contact: zhanh.he.uwa@gmail.com
#
# ## Before you start - Setup the notebook Env path:

# %%
# %cd /media/datadisk/home/22828187/zhanh/202510_hpt_smc
# %env PYTHONPATH=/media/datadisk/home/22828187/zhanh/202510_hpt_smc
# Out:
# /media/datadisk/home/22828187/zhanh/202510_hpt_smc
# env: PYTHONPATH=/media/datadisk/home/22828187/zhanh/202510_hpt_smc
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ## Evaluation on Maestro v3 Test Set (Table 1)
#
# | AMT Module | Score Module | Input2 | Input3 | frame_max error ↓ | frame_max std ↓ | onset_masked error ↓ | onset_masked std ↓ | Params |
# |---|---|---|---|---:|---:|---:|---:|---:|
# | HPT | direct | – | – | (9.46) | (9.26) | 4.59 | 6.13 | 4.07 M |
# | HPT | note editor | onset | – | (9.40) | (7.76) | 3.99 | 4.79 | 5.04 M |
# | HPT | note editor | onset | frame | (9.02) | (7.64) | 4.00 | 4.70 | 5.04 M |
# | HPT | note editor | onset | exframe | (9.55) | (7.68) | 3.91 | 4.71 | 5.04 M |
#
# Because different methods has diff post-processing preference:
# - Benchmark methods are reported with frame_max_error (MAE) and frame_max_std (STD)
# - Proposed & AMT methods are reported with onset_masked_error (MAE) and onset_masked_std (STD)
# - In this way, both are best score reported.

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="maestro" \
  model.type="hpt" \
  score_informed.method="direct" \
  model.input2="null" model.input3="null" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt/100000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hpt
# Test Set        : maestro
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt/100000_iterations.pth
# Params          : 4075336 (4075.336 K, 4.075 M)
# ================================================================================
# Kim Eval: 100%|███████████| 1276/1276 [26:25<00:00,  1.24s/file, frame_err=9.46]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 9.4623
# frame_max_std: 9.2660
# onset_masked_error: 4.5916
# onset_masked_std: 6.1334

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="maestro" \
  model.type="hpt" \
  score_informed.method="note_editor" \
  model.input2="onset" model.input3="null" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+score_note_editor/90000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hpt+onset+score_note_editor
# Test Set        : maestro
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+score_note_editor/90000_iterations.pth
# Params          : 5043401 (5043.401 K, 5.043 M)
# ================================================================================
# Kim Eval: 100%|███████████| 1276/1276 [26:41<00:00,  1.26s/file, frame_err=9.40]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 9.4009
# frame_max_std: 7.7614
# onset_masked_error: 3.9922
# onset_masked_std: 4.7943

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="maestro" \
  model.type="hpt" \
  score_informed.method="note_editor" \
  model.input2="onset" model.input3="null" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+score_note_editor/100000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hpt+onset+score_note_editor
# Test Set        : maestro
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+score_note_editor/100000_iterations.pth
# Params          : 5043401 (5043.401 K, 5.043 M)
# ================================================================================
# Kim Eval: 100%|███████████| 1276/1276 [26:48<00:00,  1.26s/file, frame_err=8.58]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 8.5753
# frame_max_std: 7.6164
# onset_masked_error: 4.0538
# onset_masked_std: 4.6937

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="maestro" \
  model.type="hpt" \
  score_informed.method="note_editor" \
  model.input2="onset" model.input3="frame" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+frame+score_note_editor/100000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hpt+onset+frame+score_note_editor
# Test Set        : maestro
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+frame+score_note_editor/100000_iterations.pth
# Params          : 5043529 (5043.529 K, 5.044 M)
# ================================================================================
# Kim Eval: 100%|███████████| 1276/1276 [28:25<00:00,  1.34s/file, frame_err=9.02]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 9.0205
# frame_max_std: 7.6497
# onset_masked_error: 4.0012
# onset_masked_std: 4.7051

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="maestro" \
  model.type="hpt" \
  score_informed.method="note_editor" \
  model.input2="onset" model.input3="exframe" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+exframe+score_note_editor/120000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hpt+onset+exframe+score_note_editor
# Test Set        : maestro
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+exframe+score_note_editor/120000_iterations.pth
# Params          : 5043529 (5043.529 K, 5.044 M)
# ================================================================================
# Kim Eval: 100%|███████████| 1276/1276 [26:41<00:00,  1.25s/file, frame_err=9.55]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 9.5545
# frame_max_std: 7.6822
# onset_masked_error: 3.9115
# onset_masked_std: 4.7122

# %% [markdown]
# ## SMD Dataset Evaluation (Table2 in Paper)
#
# | Category | Model | Variant / Setting | frame_max_error ↓ | frame_max_std ↓ | onset_masked_error ↓ | onset_masked_std ↓ | Params |
# |---|---|---|---:|---:|---:|---:|---:|
# | **Benchmark** | TransKun | AMT (pretrained) | 13.27 | 11.90 | (13.94) | (12.27) | 13.61 M |
# | **Benchmark** | FiLM-UNet | score-informed (pretrained) | 9.9 in paper (9.95) | 7.8 in paper (8.32) | (16.03) | (12.46) | 8.79 M |
# |  |  |  |  |  |  |  |  |
# | **Ours (trained)** | HPT | direct (null + null) | (11.69) | (9.13) | 10.00 | 8.79 | 4.07 M |
# | **Ours (trained)** | HPT | score-inf (onset + frame) | (15.82) | (8.90) | 8.04 | 6.91 | 5.04 M |
# | **Ours (trained)** | HPPNet | direct | (12.20) | (9.47) | 10.57 | 8.98 | 0.52 M |
# | **Ours (trained)** | HPPNet | score-inf (onset + frame) | (16.81) | (9.40) | 9.17 | 7.31 | 1.48 M |
# | **Ours (trained)** | DynEst | direct | (12.48) | (9.44) | 10.39 | 8.78 | 13.29 M |
# | **Ours (trained)** | DynEst | score-inf (onset + frame) | (16.24) | (9.26) | 8.03 | 6.85 | 14.26 M |
#
# Because different methods has diff post-processing preference:
# - Benchmark methods are reported with frame_max_error (MAE) and frame_max_std (STD)
# - Our methods are reported with onset_masked_error (MAE) and onset_masked_std (STD)
# - In this way, both are best score reported.

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="smd" \
  model.type="transkun_pretrained" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_smc/benchmarks/Transkun/transkun/pretrained/2.0.pt" \
  feature.audio_feature="logmel" feature.sample_rate=44100 feature.frames_per_second=43
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : transkun_pretrained
# Test Set        : smd
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_smc/benchmarks/Transkun/transkun/pretrained/2.0.pt
# Params          : 13613711 (13613.711 K, 13.614 M)
# ================================================================================
# Kim Eval: 100%|██████████████| 49/49 [11:53<00:00, 14.57s/file, frame_err=13.27]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 13.2741
# frame_max_std: 11.9042
# onset_masked_error: 13.9477
# onset_masked_std: 12.2757

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="smd"\
  model.type="filmunet_pretrained" \
  model.kim_condition="frame" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/2025_achieve/kim_ismir2024/pretrained/FiLMUNetPretrained+frame/1000000_iterations.pth" \
  feature.audio_feature="logmel" feature.sample_rate=16000 feature.segment_seconds=2.0 feature.hop_seconds=1.0 feature.frames_per_second=100
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : filmunet_pretrained
# Test Set        : smd
# Checkpoint      : /media/datadisk/home/22828187/zhanh/2025_achieve/kim_ismir2024/pretrained/FiLMUNetPretrained+frame/1000000_iterations.pth
# Params          : 8797563 (8797.563 K, 8.798 M)
# ================================================================================
# Kim Eval: 100%|███████████████| 49/49 [07:12<00:00,  8.83s/file, frame_err=9.96]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 9.9589
# frame_max_std: 8.3273
# onset_masked_error: 16.0383
# onset_masked_std: 12.4601

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="smd" \
  model.type="hpt" \
  score_informed.method="direct" \
  model.input2="null" model.input3="null" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt/60000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hpt
# Test Set        : smd
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt/60000_iterations.pth
# Params          : 4075336 (4075.336 K, 4.075 M)
# ================================================================================
# Kim Eval: 100%|██████████████| 49/49 [05:50<00:00,  7.15s/file, frame_err=11.69]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 11.6942
# frame_max_std: 9.1395
# onset_masked_error: 10.0069
# onset_masked_std: 8.7909

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="smd" \
  model.type="hpt" \
  score_informed.method="note_editor" \
  model.input2="onset" model.input3="frame" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+frame+score_note_editor/20000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hpt+onset+frame+score_note_editor
# Test Set        : smd
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+frame+score_note_editor/20000_iterations.pth
# Params          : 5043529 (5043.529 K, 5.044 M)
# ================================================================================
# Kim Eval: 100%|██████████████| 49/49 [06:00<00:00,  7.36s/file, frame_err=15.83]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 15.8298
# frame_max_std: 8.9055
# onset_masked_error: 8.0451
# onset_masked_std: 6.9105

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="smd" \
  model.type="hppnet" \
  score_informed.method="direct" \
  model.input2="null" model.input3="null" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hppnet/10000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hppnet
# Test Set        : smd
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hppnet/10000_iterations.pth
# Params          : 520257 (520.257 K, 0.520 M)
# ================================================================================
# Kim Eval: 100%|██████████████| 49/49 [05:18<00:00,  6.50s/file, frame_err=12.21]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 12.2082
# frame_max_std: 9.4742
# onset_masked_error: 10.5790
# onset_masked_std: 8.9894

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="smd" \
  model.type="hppnet" \
  score_informed.method="note_editor" \
  model.input2="onset" model.input3="frame" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hppnet+onset+frame+score_note_editor/20000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : hppnet+onset+frame+score_note_editor
# Test Set        : smd
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hppnet+onset+frame+score_note_editor/20000_iterations.pth
# Params          : 1488450 (1488.450 K, 1.488 M)
# ================================================================================
# Kim Eval: 100%|██████████████| 49/49 [05:39<00:00,  6.93s/file, frame_err=16.81]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 16.8141
# frame_max_std: 9.4074
# onset_masked_error: 9.1789
# onset_masked_std: 7.3182

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="smd" \
  model.type="dynest" \
  score_informed.method="direct" \
  model.input2="null" model.input3="null" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/dynest/10000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : dynest
# Test Set        : smd
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/dynest/10000_iterations.pth
# Params          : 13299288 (13299.288 K, 13.299 M)
# ================================================================================
# Kim Eval: 100%|██████████████| 49/49 [04:59<00:00,  6.11s/file, frame_err=12.48]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 12.4831
# frame_max_std: 9.4439
# onset_masked_error: 10.3942
# onset_masked_std: 8.7896

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer="single" dataset.test_set="smd" \
  model.type="dynest" \
  score_informed.method="note_editor" \
  model.input2="onset" model.input3="frame" \
  model.pretrained_checkpoint="/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/dynest+onset+frame+score_note_editor/10000_iterations.pth"
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (single checkpoint)
# Model Name      : dynest+onset+frame+score_note_editor
# Test Set        : smd
# Checkpoint      : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/dynest+onset+frame+score_note_editor/10000_iterations.pth
# Params          : 14267481 (14267.481 K, 14.267 M)
# ================================================================================
# Kim Eval: 100%|██████████████| 49/49 [05:15<00:00,  6.44s/file, frame_err=16.25]
#
# ===== Kim-style Average Metrics =====
# frame_max_error: 16.2470
# frame_max_std: 9.2601
# onset_masked_error: 8.0339
# onset_masked_std: 6.8570

# %% [markdown]
# # Reserve Part to conduct experiment in Table 2

# %%
# !python pytorch/calculate_scores.py \
  exp.run_infer=multi \
  dataset.test_set=smd \
  model.type=hpt \
  model.input2=onset model.input3=frame \
  score_informed.method=note_editor \
  +exp.eval_start_iteration=0 +exp.eval_end_iteration=10000 +exp.eval_step_iteration=10000
  # Comment out the last line (DEBUG mode) in format - group search the best eval iteration, which is very time-consuming.
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/bark_env/lib/python3.10/site-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(
# ================================================================================
# Evaluation Mode : Kim et al. (multi-checkpoint)
# Model Name      : hpt+onset+frame+score_note_editor
# Test Set        : smd
# Checkpoint Dir  : /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/hpt+onset+frame+score_note_editor
# Iterations      : 0 -> 10000 (step=10000)
# ================================================================================
# wandb: Currently logged in as: zhanh (zhanh-uwa) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run z41d02y2 (0.0s)
# wandb: ⣽ setting up run z41d02y2 (0.0s)
# wandb: ⣾ setting up run z41d02y2 (0.0s)
# wandb: ⣷ setting up run z41d02y2 (0.0s)
# wandb: Tracking run with wandb version 0.23.0
# wandb: Run data is saved locally in /media/datadisk/home/22828187/zhanh/202510_hpt_smc/wandb/run-20260224_111109-z41d02y2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eval-hpt+onset+frame+score_note_editor-smd-multi-it0_to_10000
# wandb: ⭐️ View project at https://wandb.ai/zhanh-uwa/202602_smc
# wandb: 🚀 View run at https://wandb.ai/zhanh-uwa/202602_smc/runs/z41d02y2
# [eval] iter=0 | params=5043.529 K / 5.044 M
# Kim Eval: 100%|██████████████| 49/49 [07:33<00:00,  9.26s/file, frame_err=18.16]
# [eval] iter=10000 | params=5043.529 K / 5.044 M
# Kim Eval: 100%|██████████████| 49/49 [07:31<00:00,  9.21s/file, frame_err=15.74]
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading output.log 0B/310B (0.2s)
# wandb: ⣷ uploading wandb-summary.json 0B/532B (0.2s)
# wandb: ⣯ uploading output.log 0B/310B (0.2s)
# wandb: ⣯ uploading wandb-summary.json 0B/532B (0.2s)
# wandb: ⣟ uploading output.log 0B/310B (0.2s)
# wandb: ⣟ uploading wandb-summary.json 0B/532B (0.2s)
# wandb: ⡿ uploading output.log 0B/310B (0.2s)
# wandb: ⡿ uploading wandb-summary.json 0B/532B (0.2s)
# wandb: ⢿ uploading output.log 0B/310B (0.2s)
# wandb: ⢿ uploading wandb-summary.json 0B/532B (0.2s)
# wandb: ⣻ uploading config.yaml 4.8KB/4.8KB (0.3s)
# wandb: ⣽ uploading config.yaml 4.8KB/4.8KB (0.3s)
# wandb: ⣾ uploading config.yaml 4.8KB/4.8KB (0.3s)
# wandb: ⣷ uploading config.yaml 4.8KB/4.8KB (0.3s)
# wandb: ⣯ uploading config.yaml 4.8KB/4.8KB (0.3s)
# wandb: ⣟ uploading history steps 1-1, summary, console lines 3-3 (0.4s)
# wandb:
# wandb: Run history:
# wandb:             eval/f1_score ▁▁
# wandb:        eval/frame_mask_f1 ▁▁
# wandb: eval/frame_mask_precision ▁▁
# wandb:    eval/frame_mask_recall ▁▁
# wandb:      eval/frame_max_error █▁
# wandb:        eval/frame_max_std █▁
# wandb:   eval/onset_masked_error █▁
# wandb:     eval/onset_masked_std █▁
# wandb:         eval/params_count ▁▁
# wandb:       eval/params_count_k ▁▁
# wandb:                        +4 ...
# wandb:
# wandb: Run summary:
# wandb:             eval/f1_score 0.04697
# wandb:        eval/frame_mask_f1 1
# wandb: eval/frame_mask_precision 1
# wandb:    eval/frame_mask_recall 1
# wandb:      eval/frame_max_error 15.74367
# wandb:        eval/frame_max_std 9.71793
# wandb:   eval/onset_masked_error 8.27623
# wandb:     eval/onset_masked_std 7.3007
# wandb:         eval/params_count 5043529
# wandb:       eval/params_count_k 5043.529
# wandb:                        +4 ...
# wandb:
# wandb: 🚀 View run eval-hpt+onset+frame+score_note_editor-smd-multi-it0_to_10000 at: https://wandb.ai/zhanh-uwa/202602_smc/runs/z41d02y2
# wandb: ⭐️ View project at: https://wandb.ai/zhanh-uwa/202602_smc
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260224_111109-z41d02y2/logs
#
# [done] Wrote evaluation summary: /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/kim_eval_summary/smd/hpt+onset+frame+score_note_editor/iter_summary.csv
